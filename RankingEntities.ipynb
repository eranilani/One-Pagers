# %% [markdown]
# # Ranking entities

# %%
import pandas as pd
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    
    # Import entities / skills / wikipedia
    entities = pd.read_csv("../data/classeek_entities.csv")
    skills = pd.read_csv("../data/classeek_skills.csv")
    alt_names = pd.read_csv("../data/classeek_alternative_names.csv")
    performances = pd.read_csv("../data/classeek_performances.csv")
    wikipedia_pv = pd.read_csv("../data/classeek_wikipedia_page_views.csv")
    mediamentions = pd.read_csv("../data/classeek_media_mentions.csv")
    biographies = pd.read_csv("../data/classeek_biographies.csv")

    # Import entities relations
    entities_performances = pd.read_csv("../data/classeek_entities_performances.csv")
    entities_pieces = pd.read_csv("../data/classeek_entities_pieces.csv")
    entities_skills = pd.read_csv("../data/classeek_entity_skills.csv")

# %% [markdown]
# ## Number of Performances per entity ranking

# %%
# Unique entities 
print('Total number of entities :', len(entities_performances.entity_id.unique()))
df = entities_performances.groupby('entity_id').count().sort_values('id', ascending=False)
df['count'] = df.id
df = df.loc[:, ['count']]
df.head(10)
# Out:
# Total number of entities : 110496
#                                       count
# entity_id
# 646cd5c9-e37f-4009-9daa-8d055f47c5af  22913
# 890a2d3f-4eac-4e75-87c8-871239f553b9  15646
# acf05239-b57d-436a-ab96-dc4589cd0d17   5322
# 64e2e1b0-cf8e-433e-9423-d0c2fe30aa52   4389
# bd01268d-8a66-4139-88d8-13cffa7702d8   3969
# 7aa95431-6eee-4efd-9254-8044489aacd6   3756
# 2ffe418b-f92d-400b-9b2c-8b3f53c4fa8f   2628
# 10f63486-bb13-47d4-b4da-ddc0d3b3396a   2565
# c347bc25-007f-4ea2-9ed1-385bb3eaa53a   2183
# eee8bcba-435e-4efb-995d-45686afb36fc   2130

# %%
# Quick Overview of distribution 

print('Only one performance :', round(100*len(df[df['count']==1])/len(df), 2), '%')
print('Less than two performances :', round(100*len(df[df['count']<=2])/len(df), 2), '%')
print('')
print('More than three performances :', round(100*len(df[df['count']>=3])/len(df), 2), '%')
print('More than five performances :', round(100*len(df[df['count']>=5])/len(df), 2), '%')
print('More than ten performances :', round(100*len(df[df['count']>=10])/len(df), 2), '%')
print('More than fifty performances :', round(100*len(df[df['count']>=50])/len(df), 2), '%')
print('More than a hundred performances :', round(100*len(df[df['count']>=100])/len(df), 2), '%')
# Out:
# Only one performance : 48.46 %
# Less than two performances : 70.92 %
#
# More than three performances : 29.08 %
# More than five performances : 16.84 %
# More than ten performances : 8.24 %
# More than fifty performances : 1.39 %
# More than a hundred performances : 0.58 %

# %% [markdown]
# ### Top (Most performances)

# %%
# Top 
limit = 10 
top = df.head(limit).index.to_list()

print('Top 10')
for i in range(limit) : 
    print(i, entities.loc[entities.id == top[i]].name.to_string(index = False))
# Out:
# Top 10
# 0  Boston Symphony Orchestra
# 1  New York Philharmonic
# 2  Henry Wood
# 3  Serge Koussevitzky
# 4  Bbc Symphony Orchestra
# 5  The New Queen'S Hall Orchestra
# 6  Frederick Kiddle
# 7  World Premiere
# 8  Charles Munch
# 9  New York Premiere

# %%
# Top three orchestras
top_orch = [0, 1, 4]
top_orch = df.iloc[top_orch].index.to_list()

# Top three artists 
top_artists = [2, 3, 6]
top_artists = df.iloc[top_artists].index.to_list()

# %% [markdown]
# ### Only three performances

# %%
# At least 3 to prevent selecting isolated cases (aliases)
limit = 10 
three_perf = df[df['count']==3].head(limit).index.to_list()

print('10 examples with 3 performances')
for i in range(limit) : 
    print(i, entities.loc[entities.id == three_perf[i]].name.to_string(index = False))
# Out:
# 10 examples with 3 performances
# 0  Leslie Amper
# 1  Eunice Kim
# 2  Ensemble Les Surprises
# 3  Francesca Braggiotti
# 4  Milos Bulajic
# 5  Dominique A
# 6  Santiago Rodriguez
# 7  Hank Roberts
# 8  Davide Lattuada
# 9  Martine Ritz

# %%
# Three artists 
low_artists = [0, 1, 2]
low_artists = df[df['count']==3].iloc[low_artists].index.to_list()

# %% [markdown]
# ## Basic information for one pager

# %%
# Wanted Information 
infos = ['id', 'name', 'gender', 'alive', 'birth_date', 'death_date', 'current_influence_percentile']
entities.head(3)
# Out:
#    Unnamed: 0                                    id    parameterized_name  \
# 0           0  bc8a649f-10fe-4685-9164-859499b6b06a        antonin_dvorak
# 1           1  e5f113de-59b1-4624-9a43-d60747c57602     leonard_bernstein
# 2           2  291f205d-2090-49bb-a1ba-454c1cd26141  ludwig_van_beethoven
#
#                    name                  created_at  \
# 0        Antonín Dvořák  2019-05-23 09:55:52.711701
# 1     Leonard Bernstein  2019-04-10 22:34:21.328525
# 2  Ludwig Van Beethoven  2019-04-10 22:56:12.313574
#
#                    updated_at  gender  alive birth_date death_date  kind  \
# 0  2020-04-30 14:05:38.223370     NaN  False        NaN        NaN     0
# 1  2020-04-30 14:10:50.742145     NaN  False        NaN        NaN     0
# 2  2020-04-30 14:10:52.466085     NaN  False        NaN        NaN     0
#
#    not_usable  accepted  qa_flags  action_in_progress  \
# 0       False     False         0                 NaN
# 1       False     False         0                 NaN
# 2        True      True         0                 NaN
#
#    current_influence_percentile
# 0                           NaN
# 1                           NaN
# 2                           NaN

# %% [markdown]
# #### Get infos for list of ids

# %%
def get_info_for_list(id_list) : 
    
    entity_infos = ['id', 'name', 'gender', 'alive', 'birth_date', 'death_date', 'current_influence_percentile']
    df_info = entities[entities.id.apply(lambda x: x in id_list)].loc[:, entity_infos]
    
    return  df_info

# %% [markdown]
# ### Top Orchestras

# %%
info_top_orch = get_info_for_list(top_orch)
info_top_orch
# Out:
#                                           id                       name  \
# 75839   646cd5c9-e37f-4009-9daa-8d055f47c5af  Boston Symphony Orchestra
# 76833   bd01268d-8a66-4139-88d8-13cffa7702d8     Bbc Symphony Orchestra
# 146737  890a2d3f-4eac-4e75-87c8-871239f553b9      New York Philharmonic
#
#         gender alive birth_date death_date  current_influence_percentile
# 75839      NaN  True        NaN        NaN                          99.0
# 76833      NaN  True        NaN        NaN                          99.0
# 146737     NaN  True        NaN        NaN                           NaN

# %% [markdown]
# ### Top Artists

# %%
info_top_artists = get_info_for_list(top_artists)
info_top_artists
# Out:
#                                          id                name  gender  \
# 15453  2ffe418b-f92d-400b-9b2c-8b3f53c4fa8f    Frederick Kiddle     NaN
# 76419  64e2e1b0-cf8e-433e-9423-d0c2fe30aa52  Serge Koussevitzky     NaN
# 81967  acf05239-b57d-436a-ab96-dc4589cd0d17          Henry Wood     NaN
#
#        alive birth_date death_date  current_influence_percentile
# 15453   True        NaN        NaN                           NaN
# 76419  False        NaN        NaN                           NaN
# 81967   True        NaN        NaN                          78.0

# %% [markdown]
# ### Entities with less performances

# %%
info_low_artists = get_info_for_list(low_artists)
info_low_artists
# Out:
#                                          id                    name  gender  \
# 75484  986c8d27-9fc3-4f3c-9314-8401e4bec003  Ensemble Les Surprises     NaN
# 81704  ddd9bb4b-8965-4046-8b20-9b2f273fe0d9              Eunice Kim     NaN
# 88062  b6f086e1-56d8-4bd3-b6ff-1f01cf9c533c            Leslie Amper     NaN
#
#       alive birth_date death_date  current_influence_percentile
# 75484  True        NaN        NaN                          53.0
# 81704  True        NaN        NaN                          38.0
# 88062  True        NaN        NaN                           NaN

# %% [markdown]
# ### Gauthier Capuçon / Renaud Capuçon
# - Gauthier Capuçon / id = 149b70fa-a190-4a83-bea9-38dafc1d4c5c
# - Renaud Capuçon / id = d414cdfd-b2c4-4d9f-adce-7c1a6d03d162

# %%
entities[entities.parameterized_name.str.contains('capucon')]
# Out:
#         Unnamed: 0                                    id  \
# 758            758  149b70fa-a190-4a83-bea9-38dafc1d4c5c
# 2542          2542  4a3cc23c-93c9-4a25-a0fa-e1a6be452cea
# 2760          2760  de876f79-75c7-4344-887f-fb5a633ad7b0
# 91354        91354  df73982b-5aa7-4cfc-9374-40f016652d94
# 91709        91709  ea4da749-eab4-4359-9c26-bad2c90403d9
# 91936        91936  7d6898fc-6690-454f-92ae-baef14f1a4f8
# 91940        91940  8f630e74-5c0e-4325-a708-1caf68409a1f
# 91952        91952  845498f4-98ab-4def-b1a7-d716c493e6dc
# 145377      145377  d414cdfd-b2c4-4d9f-adce-7c1a6d03d162
# 154805      154805  c0aa2525-6986-43ff-b8df-30620b30b670
# 154815      154815  720177b5-1129-414c-8379-178e6ce4cdc8
#
#                                        parameterized_name  \
# 758                                       gautier_capucon
# 2542                     renaud_capucon_lausanne_soloists
# 2760                               quatuor_renaud_capucon
# 91354           renaud_capucongautier_capuconfrank_braley
# 91709      renaud_capucongautier_capuconnicholas_angelich
# 91936   staatskapelle_de_dresdedaniel_hardingrenaud_ca...
# 91940   les_grands_solistesgautier_capucongabriela_mon...
# 91952   renaud_capuconnicholas_angelichles_grands_soli...
# 145377                                     renaud_capucon
# 154805                            gautier_capucon_capucon
# 154815                             renaud_capucon_capucon
#
#                                                      name  \
# 758                                       Gautier Capuçon
# 2542                   Renaud Capuçon - Lausanne Soloists
# 2760                               Quatuor Renaud Capuçon
# 91354           Renaud Capucongautier Capuconfrank Braley
# 91709      Renaud Capuçongautier Capuçonnicholas Angelich
# 91936   Staatskapelle De Dresdedaniel Hardingrenaud Ca...
# 91940   Les Grands Solistesgautier Capuçongabriela Mon...
# 91952   Renaud Capuconnicholas Angelichles Grands Soli...
# 145377                                     Renaud Capuçon
# 154805                          Gautier Capucon (Capuçon)
# 154815                           Renaud Capucon (Capuçon)
#
#                         created_at                  updated_at  gender alive  \
# 758     2019-04-10 22:00:12.231805  2020-06-26 09:30:20.168532     NaN  True
# 2542    2020-07-15 08:03:00.308463  2020-07-26 08:05:15.398801     NaN  True
# 2760    2019-04-10 23:25:28.865209  2019-04-10 23:25:28.865209     NaN  True
# 91354   2019-04-10 22:26:17.504720  2020-04-07 15:30:49.093605     NaN  True
# 91709   2019-04-10 22:56:23.356138  2020-04-07 15:31:09.168588     NaN  True
# 91936   2019-04-10 23:19:19.813299  2020-04-07 15:27:46.825796     NaN  True
# 91940   2019-04-10 23:19:19.702935  2020-04-07 15:28:20.046161     NaN  True
# 91952   2019-04-10 23:25:42.967559  2020-04-07 15:27:59.407880     NaN  True
# 145377  2019-04-05 22:00:26.753946  2020-06-26 09:40:24.063956     NaN  True
# 154805  2020-04-10 01:30:54.770641  2020-04-10 01:30:54.770641     NaN  True
# 154815  2020-04-10 01:32:11.838321  2020-04-10 01:32:11.838321     NaN  True
#
#        birth_date death_date  kind  not_usable  accepted  qa_flags  \
# 758           NaN        NaN     0       False     False         0
# 2542          NaN        NaN     0        True      True         0
# 2760          NaN        NaN     0       False     False         0
# 91354         NaN        NaN     0        True     False         1
# 91709         NaN        NaN     0        True     False         1
# 91936         NaN        NaN     0        True     False         1
# 91940         NaN        NaN     0        True     False         1
# 91952         NaN        NaN     0        True     False         1
# 145377        NaN        NaN     0       False     False         0
# 154805        NaN        NaN     0        True     False         0
# 154815        NaN        NaN     0        True     False         0
#
#         action_in_progress  current_influence_percentile
# 758                    NaN                          99.0
# 2542                   NaN                          38.0
# 2760                   NaN                           NaN
# 91354                  NaN                           NaN
# 91709                  NaN                           NaN
# 91936                  NaN                           NaN
# 91940                  NaN                           NaN
# 91952                  NaN                           NaN
# 145377                 NaN                          99.0
# 154805                 NaN                           NaN
# 154815                 NaN                           NaN

# %% [markdown]
# ### IDs
#
# - Gauthier Capuçon : 149b70fa-a190-4a83-bea9-38dafc1d4c5c
# - Renaud Capuçon : d414cdfd-b2c4-4d9f-adce-7c1a6d03d162
